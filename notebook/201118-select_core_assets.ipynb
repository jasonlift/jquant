# %%
from tushare_login import pro

# %% [markdown]
# ### 三大报表

# %%
pro.income(ts_code='300760.SZ', start_date='20200101', end_date='20200730')
# Out:
#      ts_code  ann_date f_ann_date  end_date report_type comp_type  basic_eps  \
# 0  300760.SZ  20200429   20200429  20200331           1         1     1.0803
# 1  300760.SZ  20200402   20200402  20191231           1         1     3.8500
# 2  300760.SZ  20200402   20200402  20191231           1         1     3.8500
#
#    diluted_eps  total_revenue       revenue  ... minority_gain  \
# 0       1.0803   4.741267e+09  4.741267e+09  ...      495942.0
# 1       3.8500   1.655599e+10  1.655599e+10  ...     4170049.0
# 2       3.8500   1.655599e+10  1.655599e+10  ...     4170049.0
#
#   oth_compr_income t_compr_income compr_inc_attr_p compr_inc_attr_m_s  \
# 0        7033623.0   1.320807e+09     1.320311e+09           495942.0
# 1      -19328804.0   4.665488e+09     4.661318e+09          4170049.0
# 2      -19328804.0   4.665488e+09     4.661318e+09          4170049.0
#
#            ebit        ebitda insurance_exp undist_profit distable_profit
# ...

# %%
pro.balancesheet(ts_code='300760.SZ', start_date='20200101', end_date='20200730')
# Out:
#      ts_code  ann_date f_ann_date  end_date report_type comp_type  \
# 0  300760.SZ  20200429   20200429  20200331           1         1
# 1  300760.SZ  20200429   20200429  20200331           1         1
# 2  300760.SZ  20200402   20200402  20191231           1         1
# 3  300760.SZ  20200402   20200402  20191231           1         1
#
#     total_share      cap_rese  undistr_porfit  surplus_rese  ...  \
# 0  1.215691e+09  8.171270e+09    9.903225e+09   607845633.0  ...
# 1  1.215691e+09  8.171270e+09    9.903225e+09   607845633.0  ...
# 2  1.215691e+09  8.171270e+09    8.599613e+09   607845633.0  ...
# 3  1.215691e+09  8.171270e+09    8.599613e+09   607845633.0  ...
#
#   lt_payroll_payable  oth_comp_income oth_eqt_tools  oth_eqt_tools_p_shr  \
# 0       9.457143e+08        5724776.0          None                 None
# 1       9.457143e+08        5724776.0          None                 None
# 2       1.424008e+09       -1308847.0          None                 None
# ...

# %%
pro.cashflow(ts_code='300760.SZ', start_date='20200101', end_date='20200730')
# Out:
#      ts_code  ann_date f_ann_date  end_date comp_type report_type  \
# 0  300760.SZ  20200429   20200429  20200331         1           1
# 1  300760.SZ  20200402   20200402  20191231         1           1
# 2  300760.SZ  20200402   20200402  20191231         1           1
#
#      net_profit  finan_exp  c_fr_sale_sg  recp_tax_rends  ...      others  \
# 0           NaN        NaN  5.626128e+09     117963119.0  ...         NaN
# 1  4.684817e+09 -6734191.0  1.845723e+10     382131126.0  ... -13957747.0
# 2  4.684817e+09 -6734191.0  1.845723e+10     382131126.0  ... -13957747.0
#
#   im_net_cashflow_oper_act conv_debt_into_cap conv_copbonds_due_within_1y  \
# 0                      NaN               None                        None
# 1             4.721795e+09               None                        None
# 2             4.721795e+09               None                        None
#
#   fa_fnc_leases  end_bal_cash  beg_bal_cash end_bal_cash_equ beg_bal_cash_equ  \
# ...
